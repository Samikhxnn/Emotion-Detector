# %% [markdown]
# <a href="https://colab.research.google.com/github/Samikhxnn/Emotion-Detector/blob/main/Emotion_Detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model=YOLO()
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
model.train(data="/content/drive/MyDrive/mydata/data.yaml",
            epochs=300,
            imgsz=620,
            batch=16)
# Out:
# Ultralytics 8.4.50 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model=YOLO('/content/runs/detect/train/weights/best.pt')

# %%
result=model.predict("/content/drive/MyDrive/videoplayback.mp4",save=True,stream=True)
for r in result:
  pass
# Out:
# video 1/1 (frame 1/686) /content/drive/MyDrive/videoplayback.mp4: 640x384 1 sad, 58.7ms
# video 1/1 (frame 2/686) /content/drive/MyDrive/videoplayback.mp4: 640x384 1 sad, 17.3ms
# video 1/1 (frame 3/686) /content/drive/MyDrive/videoplayback.mp4: 640x384 1 sad, 15.0ms
# video 1/1 (frame 4/686) /content/drive/MyDrive/videoplayback.mp4: 640x384 1 sad, 10.3ms
# video 1/1 (frame 5/686) /content/drive/MyDrive/videoplayback.mp4: 640x384 1 sad, 9.7ms
# video 1/1 (frame 6/686) /content/drive/MyDrive/videoplayback.mp4: 640x384 1 sad, 10.3ms
# video 1/1 (frame 7/686) /content/drive/MyDrive/videoplayback.mp4: 640x384 (no detections), 9.8ms
# video 1/1 (frame 8/686) /content/drive/MyDrive/videoplayback.mp4: 640x384 (no detections), 10.9ms
# video 1/1 (frame 9/686) /content/drive/MyDrive/videoplayback.mp4: 640x384 (no detections), 9.7ms
# video 1/1 (frame 10/686) /content/drive/MyDrive/videoplayback.mp4: 640x384 (no detections), 9.6ms
# ...
